-- %% [markdown]
-- # **Credit Collections Behavior Model: PTP Funnel, Risk Segments, and Recovery Cohorts**

-- %% [markdown]
-- Structured queries powering cohort analysis and PTP conversion modeling across risk bands and outreach channels.

-- %% [markdown]
-- ## **1\. Accounts by Risk Band**
--
-- ### How many accounts fall into each credit risk tier (A–E)

-- %%
SELECT risk_band, COUNT(*) AS num_accounts
FROM dbo.accounts
GROUP BY risk_band
ORDER BY risk_band;
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:01.141
-- <table><tr><th>risk_band</th><th>num_accounts</th></tr><tr><td>A</td><td>21993</td></tr><tr><td>B</td><td>26082</td></tr><tr><td>C</td><td>24028</td></tr><tr><td>D</td><td>17900</td></tr><tr><td>E</td><td>9997</td></tr></table>

-- %% [markdown]
-- ## **2\. Credit Limit Stats (Min, Max, Avg, Median)**
--
-- ### Profile the overall credit limit distribution

-- %%
SELECT DISTINCT
  MIN(credit_limit) OVER () AS min_limit,
  MAX(credit_limit) OVER () AS max_limit,
  AVG(credit_limit) OVER () AS avg_limit,
  PERCENTILE_CONT(0.5) WITHIN GROUP (ORDER BY credit_limit) OVER () AS median_limit
FROM dbo.accounts;
-- Out:
-- : Msg 8117, Level 16, State 1, Line 4
-- Operand data type nvarchar(max) is invalid for avg operator.
-- Total execution time: 00:00:00.062

-- %% [markdown]
-- ## **3\. Accounts by Country and Region**
--
-- ### Geographic distribution of accounts.

-- %%
SELECT country, region, COUNT(*) AS total
FROM dbo.accounts
GROUP BY country, region
ORDER BY total DESC;
-- Out:
-- (26 rows affected)
-- Total execution time: 00:00:13.438
-- <table><tr><th>country</th><th>region</th><th>total</th></tr><tr><td>CA</td><td>NS</td><td>4699</td></tr><tr><td>CA</td><td>SK</td><td>4655</td></tr><tr><td>CA</td><td>MB</td><td>4648</td></tr><tr><td>CA</td><td>PE</td><td>4648</td></tr><tr><td>CA</td><td>QC</td><td>4629</td></tr><tr><td>CA</td><td>BC</td><td>4617</td></tr><tr><td>CA</td><td>YT</td><td>4610</td></tr><tr><td>CA</td><td>AB</td><td>4594</td></tr><tr><td>CA</td><td>NL</td><td>4576</td></tr><tr><td>CA</td><td>NU</td><td>4574</td></tr><tr><td>CA</td><td>ON</td><td>4568</td></tr><tr><td>CA</td><td>NT</td><td>4535</td></tr><tr><td>CA</td><td>NB</td><td>4507</td></tr><tr><td>US</td><td>NC</td><td>3180</td></tr><tr><td>US</td><td>PA</td><td>3171</td></tr><tr><td>US</td><td>NY</td><td>3136</td></tr><tr><td>US</td><td>MI</td><td>3112</td></tr><tr><td>US</td><td>CA</td><td>3110</td></tr><tr><td>US</td><td>OH</td><td>3096</td></tr><tr><td>US</td><td>VA</td><td>3083</td></tr><tr><td>US</td><td>FL</td><td>3074</td></tr><tr><td>US</td><td>GA</td><td>3065</td></tr><tr><td>US</td><td>MA</td><td>3062</td></tr><tr><td>US</td><td>TX</td><td>3028</td></tr><tr><td>US</td><td>WA</td><td>3013</td></tr><tr><td>US</td><td>IL</td><td>3010</td></tr></table>

-- %% [markdown]
-- ## **4\. DPD Bucket by Month**
--
-- ### Monthly delinquency profile by how late customers are

-- %%
SELECT
  DATETRUNC(MONTH, CAST(snapshot_month AS DATE)) AS month,
  dpd_bucket,
  COUNT(*) AS accounts
FROM dbo.deliqunecy
GROUP BY DATETRUNC(MONTH, CAST(snapshot_month AS DATE)) , dpd_bucket
ORDER BY month, dpd_bucket DESC;
-- Out:
-- (40 rows affected)
-- Total execution time: 00:00:16.215
-- <table><tr><th>month</th><th>dpd_bucket</th><th>accounts</th></tr><tr><td>2025-01-01</td><td>90</td><td>3473</td></tr><tr><td>2025-01-01</td><td>60</td><td>4605</td></tr><tr><td>2025-01-01</td><td>30</td><td>9140</td></tr><tr><td>2025-01-01</td><td>120</td><td>1960</td></tr><tr><td>2025-01-01</td><td>0</td><td>80822</td></tr><tr><td>2025-02-01</td><td>90</td><td>4926</td></tr><tr><td>2025-02-01</td><td>60</td><td>5921</td></tr><tr><td>2025-02-01</td><td>30</td><td>10138</td></tr><tr><td>2025-02-01</td><td>120</td><td>5355</td></tr><tr><td>2025-02-01</td><td>0</td><td>73660</td></tr><tr><td>2025-03-01</td><td>90</td><td>6088</td></tr><tr><td>2025-03-01</td><td>60</td><td>6705</td></tr><tr><td>2025-03-01</td><td>30</td><td>10758</td></tr><tr><td>2025-03-01</td><td>120</td><td>8221</td></tr><tr><td>2025-03-01</td><td>0</td><td>68228</td></tr><tr><td>2025-04-01</td><td>90</td><td>7040</td></tr><tr><td>2025-04-01</td><td>60</td><td>7375</td></tr><tr><td>2025-04-01</td><td>30</td><td>10915</td></tr><tr><td>2025-04-01</td><td>120</td><td>10555</td></tr><tr><td>2025-04-01</td><td>0</td><td>64115</td></tr><tr><td>2025-05-01</td><td>90</td><td>7974</td></tr><tr><td>2025-05-01</td><td>60</td><td>7744</td></tr><tr><td>2025-05-01</td><td>30</td><td>11088</td></tr><tr><td>2025-05-01</td><td>120</td><td>12400</td></tr><tr><td>2025-05-01</td><td>0</td><td>60794</td></tr><tr><td>2025-06-01</td><td>90</td><td>8509</td></tr><tr><td>2025-06-01</td><td>60</td><td>8273</td></tr><tr><td>2025-06-01</td><td>30</td><td>11207</td></tr><tr><td>2025-06-01</td><td>120</td><td>13983</td></tr><tr><td>2025-06-01</td><td>0</td><td>58028</td></tr><tr><td>2025-07-01</td><td>90</td><td>9134</td></tr><tr><td>2025-07-01</td><td>60</td><td>8568</td></tr><tr><td>2025-07-01</td><td>30</td><td>11508</td></tr><tr><td>2025-07-01</td><td>120</td><td>15010</td></tr><tr><td>2025-07-01</td><td>0</td><td>55780</td></tr><tr><td>2025-08-01</td><td>90</td><td>9651</td></tr><tr><td>2025-08-01</td><td>60</td><td>8892</td></tr><tr><td>2025-08-01</td><td>30</td><td>11550</td></tr><tr><td>2025-08-01</td><td>120</td><td>15868</td></tr><tr><td>2025-08-01</td><td>0</td><td>54039</td></tr></table>

-- %% [markdown]
-- ## **5\. DPD by Risk Band**
--
-- ### Compare late-payment severity across risk levels.

-- %%
SELECT
  a.risk_band,
  d.dpd_bucket,
  COUNT(*) AS accounts
FROM dbo.deliqunecy d
JOIN dbo.accounts a ON d.account_id = a.account_id
GROUP BY a.risk_band, d.dpd_bucket
ORDER BY a.risk_band, d.dpd_bucket;
-- Out:
-- (25 rows affected)
-- Total execution time: 00:01:06.718
-- <table><tr><th>risk_band</th><th>dpd_bucket</th><th>accounts</th></tr><tr><td>A</td><td>0</td><td>144194</td></tr><tr><td>A</td><td>120</td><td>3613</td></tr><tr><td>A</td><td>30</td><td>15730</td></tr><tr><td>A</td><td>60</td><td>7263</td></tr><tr><td>A</td><td>90</td><td>5144</td></tr><tr><td>B</td><td>0</td><td>155088</td></tr><tr><td>B</td><td>120</td><td>8837</td></tr><tr><td>B</td><td>30</td><td>22194</td></tr><tr><td>B</td><td>60</td><td>12329</td></tr><tr><td>B</td><td>90</td><td>10208</td></tr><tr><td>C</td><td>0</td><td>117929</td></tr><tr><td>C</td><td>120</td><td>20514</td></tr><tr><td>C</td><td>30</td><td>22516</td></tr><tr><td>C</td><td>60</td><td>16068</td></tr><tr><td>C</td><td>90</td><td>15197</td></tr><tr><td>D</td><td>0</td><td>68956</td></tr><tr><td>D</td><td>120</td><td>28136</td></tr><tr><td>D</td><td>30</td><td>16720</td></tr><tr><td>D</td><td>60</td><td>13832</td></tr><tr><td>D</td><td>90</td><td>15556</td></tr><tr><td>E</td><td>0</td><td>29299</td></tr><tr><td>E</td><td>120</td><td>22252</td></tr><tr><td>E</td><td>30</td><td>9144</td></tr><tr><td>E</td><td>60</td><td>8591</td></tr><tr><td>E</td><td>90</td><td>10690</td></tr></table>

-- %% [markdown]
-- ## **6\. Outreach Outcome Counts by Channel**
--
-- ### how many contact attempts were made and what happened.

-- %%
SELECT
  channel,
  outcome,
  COUNT(*) AS attempts
FROM dbo.outreach
GROUP BY channel, outcome
ORDER BY channel, outcome;
-- Out:
-- (12 rows affected)
-- Total execution time: 00:00:24.625
-- <table><tr><th>channel</th><th>outcome</th><th>attempts</th></tr><tr><td>AgentCall</td><td>LeftVM</td><td>10228</td></tr><tr><td>AgentCall</td><td>NoAnswer</td><td>18306</td></tr><tr><td>AgentCall</td><td>PTP</td><td>25783</td></tr><tr><td>AgentCall</td><td>Reached</td><td>48322</td></tr><tr><td>Email</td><td>LeftVM</td><td>20351</td></tr><tr><td>Email</td><td>NoAnswer</td><td>87818</td></tr><tr><td>Email</td><td>PTP</td><td>20767</td></tr><tr><td>Email</td><td>Reached</td><td>75712</td></tr><tr><td>SMS</td><td>LeftVM</td><td>26267</td></tr><tr><td>SMS</td><td>NoAnswer</td><td>86289</td></tr><tr><td>SMS</td><td>PTP</td><td>39193</td></tr><tr><td>SMS</td><td>Reached</td><td>110537</td></tr></table>

-- %% [markdown]
-- ## **7\. PTP Rate by Channel**
--
-- ### What % of contacts resulted in a “Promise to Pay” (PTP), by channel.

-- %%
SELECT
  channel,
  COUNT(*) AS total_attempts,
  SUM(CASE WHEN outcome = 'PTP' THEN 1 ELSE 0 END) AS ptp_count,
  1.0 * SUM(CASE WHEN outcome = 'PTP' THEN 1 ELSE 0 END) / COUNT(*) AS ptp_rate
FROM dbo.outreach
GROUP BY channel
ORDER BY ptp_rate DESC;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:09.270
-- <table><tr><th>channel</th><th>total_attempts</th><th>ptp_count</th><th>ptp_rate</th></tr><tr><td>AgentCall</td><td>102639</td><td>25783</td><td>0.251200810608</td></tr><tr><td>SMS</td><td>262286</td><td>39193</td><td>0.149428486461</td></tr><tr><td>Email</td><td>204648</td><td>20767</td><td>0.101476681912</td></tr></table>

-- %% [markdown]
-- ## **8\. Kept vs Broken Promises**
--
-- ### How many PTPs were honored versus broken.

-- %%
SELECT
  kept_promise,
  COUNT(*) AS num_accounts
FROM dbo.followup
GROUP BY kept_promise;
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:05.220
-- <table><tr><th>kept_promise</th><th>num_accounts</th></tr><tr><td>True</td><td>52415</td></tr><tr><td>False</td><td>33328</td></tr></table>

-- %% [markdown]
-- ## **9\. PTP Kept Rate by Channel**
--
-- ### how effective each contact method is at generating real payments.

-- %%
SELECT
  o.channel,
  COUNT(*) AS ptp_total,
  SUM(CASE WHEN f.kept_promise = 'True' THEN 1 ELSE 0 END) AS ptp_kept,
  1.0 * SUM(CASE WHEN f.kept_promise = 'True' THEN 1 ELSE 0 END) / COUNT(*) AS ptp_kept_rate
FROM dbo.followup f
JOIN dbo.outreach o ON f.contact_id = o.contact_id
GROUP BY o.channel
ORDER BY ptp_kept_rate DESC;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:20.956
-- <table><tr><th>channel</th><th>ptp_total</th><th>ptp_kept</th><th>ptp_kept_rate</th></tr><tr><td>Email</td><td>20767</td><td>12728</td><td>0.612895459141</td></tr><tr><td>SMS</td><td>39193</td><td>23973</td><td>0.611665348404</td></tr><tr><td>AgentCall</td><td>25783</td><td>15714</td><td>0.609471357095</td></tr></table>

-- %% [markdown]
-- ## **10\. Top 10 Largest Payments**
--
-- ### Spot the biggest individual payments made.

-- %%
SELECT TOP 10 *
FROM dbo.payments
ORDER BY amount DESC;
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:01.996
-- <table><tr><th>payment_id</th><th>account_id</th><th>payment_date</th><th>amount</th><th>method</th></tr><tr><td>3007944</td><td>72002</td><td>2025-04-08</td><td>999.99</td><td>Card</td></tr><tr><td>7005581</td><td>31806</td><td>2025-08-07</td><td>999.99</td><td>ACH</td></tr><tr><td>4001274</td><td>46114</td><td>2025-05-13</td><td>999.95</td><td>Cash</td></tr><tr><td>3003890</td><td>57542</td><td>2025-04-07</td><td>999.94</td><td>ACH</td></tr><tr><td>4001560</td><td>4529</td><td>2025-05-26</td><td>999.93</td><td>Cash</td></tr><tr><td>7004910</td><td>12673</td><td>2025-08-07</td><td>999.89</td><td>Card</td></tr><tr><td>4002562</td><td>43284</td><td>2025-05-01</td><td>999.88</td><td>Card</td></tr><tr><td>7005386</td><td>14370</td><td>2025-08-28</td><td>999.85</td><td>ACH</td></tr><tr><td>2001184</td><td>40962</td><td>2025-03-22</td><td>999.81</td><td>ACH</td></tr><tr><td>6002684</td><td>396</td><td>2025-07-01</td><td>999.79</td><td>Card</td></tr></table>

-- %% [markdown]
-- ## **11\. Payment Method Usage (Fixed Type Casting)**
--
-- ### See volume and value per payment method.

-- %%
SELECT
  method,
  COUNT(*) AS count,
  SUM(CAST(amount AS DECIMAL(12,2))) AS total_amount,
  AVG(CAST(amount AS DECIMAL(12,2))) AS avg_amount
FROM dbo.payments
GROUP BY method
ORDER BY total_amount DESC;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:07.357
-- <table><tr><th>method</th><th>count</th><th>total_amount</th><th>avg_amount</th></tr><tr><td>ACH</td><td>57189</td><td>74324497.36</td><td>1299.629253</td></tr><tr><td>Card</td><td>34817</td><td>45521942.04</td><td>1307.463079</td></tr><tr><td>Cash</td><td>10426</td><td>13794430.62</td><td>1323.079859</td></tr></table>

-- %% [markdown]
-- ## **12\. Avg Payment by Risk Band (Fixed)**
--
-- ### Are higher-risk accounts paying less?

-- %%
SELECT
  a.risk_band,
  COUNT(p.payment_id) AS num_payments,
  AVG(CAST(p.amount AS DECIMAL(12,2))) AS avg_payment,
  SUM(CAST(p.amount AS DECIMAL(12,2))) AS total_payment
FROM dbo.payments p
JOIN dbo.accounts a ON p.account_id = a.account_id
GROUP BY a.risk_band
ORDER BY a.risk_band;
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:19.778
-- <table><tr><th>risk_band</th><th>num_payments</th><th>avg_payment</th><th>total_payment</th></tr><tr><td>A</td><td>11439</td><td>1084.764053</td><td>12408616.01</td></tr><tr><td>B</td><td>19397</td><td>1171.035221</td><td>22714570.19</td></tr><tr><td>C</td><td>26705</td><td>1290.292736</td><td>34457267.54</td></tr><tr><td>D</td><td>26791</td><td>1407.084521</td><td>37697201.41</td></tr><tr><td>E</td><td>18100</td><td>1456.531208</td><td>26363214.87</td></tr></table>

-- %% [markdown]
-- ## **13\. 30 → 60 Day Roll Rates**
--
-- ### What % of 30-day late accounts rolled to 60 days next month.

-- %%
WITH d AS (
  SELECT account_id, CAST(snapshot_month AS DATE) AS snapshot_month, dpd_bucket
  FROM dbo.deliqunecy
),
next_dpd AS (
  SELECT
    d1.account_id,
    DATETRUNC(MONTH, d1.snapshot_month) AS month,
    d1.dpd_bucket AS dpd_start,
    d2.dpd_bucket AS dpd_next
  FROM d d1
  JOIN d d2
    ON d1.account_id = d2.account_id
    AND DATEADD(MONTH, 1, d1.snapshot_month) = d2.snapshot_month
  WHERE d1.dpd_bucket = 30
)
SELECT
  month,
  COUNT(*) AS was_30,
  SUM(CASE WHEN dpd_next = 60 THEN 1 ELSE 0 END) AS moved_60,
  1.0 * SUM(CASE WHEN dpd_next = 60 THEN 1 ELSE 0 END) / COUNT(*) AS roll_rate_30_to_60
FROM next_dpd
GROUP BY month
ORDER BY month;
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:22.084
-- <table><tr><th>month</th><th>was_30</th><th>moved_60</th><th>roll_rate_30_to_60</th></tr><tr><td>2025-01-01</td><td>9140</td><td>1370</td><td>0.149890590809</td></tr><tr><td>2025-02-01</td><td>10138</td><td>1447</td><td>0.142730321562</td></tr><tr><td>2025-03-01</td><td>10758</td><td>1458</td><td>0.135527049637</td></tr><tr><td>2025-04-01</td><td>10915</td><td>1442</td><td>0.132111772789</td></tr><tr><td>2025-05-01</td><td>11088</td><td>1459</td><td>0.131583694083</td></tr><tr><td>2025-06-01</td><td>11207</td><td>1500</td><td>0.133844918354</td></tr><tr><td>2025-07-01</td><td>11508</td><td>1550</td><td>0.134688912061</td></tr></table>

-- %% [markdown]
-- ## **14\. Days Between Outreach and Payment**
--
-- ### Time lag between contact attempt and payment.

-- %%
SELECT TOP 100
  o.account_id,
  o.contact_date,
  p.payment_date,
-- %% [markdown]
-- ## **16\. Creating Final View for Dashboard**

-- %%
CREATE OR ALTER VIEW vw_collections_dashboard AS
SELECT
  -- Account info
  a.account_id,
  ISNULL(a.risk_band, 'Unknown') AS risk_band,
  ISNULL(a.credit_limit, 0.00) AS credit_limit,
  ISNULL(a.region, 'Unknown') AS region,
  ISNULL(a.country, 'Unknown') AS country,

  -- Delinquency snapshot
  CAST(d.snapshot_month AS DATE) AS snapshot_month,
  CONVERT(VARCHAR(7), CAST(d.snapshot_month AS DATE), 120) AS snapshot_month_str,
  ISNULL(d.dpd_bucket, 0) AS dpd_bucket,

  -- Derived delinquency flags
  CASE WHEN d.dpd_bucket > 0 THEN 1 ELSE 0 END AS is_delinquent,
  CASE d.dpd_bucket
    WHEN 0 THEN 0
    WHEN 30 THEN 1
    WHEN 60 THEN 2
    WHEN 90 THEN 3
    WHEN 120 THEN 4
    ELSE NULL
  END AS dpd_severity_score,

  -- Payments (aggregated)
  ISNULL(p.last_payment_date, NULL) AS last_payment_date,
  ISNULL(p.total_payments, 0.00) AS total_payments,
  ISNULL(p.avg_payment, 0.00) AS avg_payment,

  -- Outreach
  ISNULL(o.contact_date, NULL) AS contact_date,
  ISNULL(o.channel, 'None') AS channel,
  ISNULL(o.outcome, 'None') AS outcome,
  CASE WHEN o.outcome = 'PTP' THEN 1 ELSE 0 END AS has_ptp,

  -- PTP follow-up
  ISNULL(f.ptp_payment_due, NULL) AS ptp_payment_due,
  ISNULL(f.kept_promise, 'None') AS kept_promise,
  CASE 
    WHEN f.kept_promise = 'True' THEN 1
    WHEN f.kept_promise = 'False' THEN 0
    ELSE NULL
  END AS ptp_kept_score,
  CASE 
    WHEN f.kept_promise = 'True' THEN 'Kept'
    WHEN f.kept_promise = 'False' THEN 'Broken'
    ELSE 'None'
  END AS ptp_outcome,

  -- Channel rank (for funnel sorting)
  CASE o.channel
    WHEN 'SMS' THEN 1
    WHEN 'Email' THEN 2
    WHEN 'AgentCall' THEN 3
    ELSE 4
  END AS last_contact_channel_rank

FROM dbo.deliqunecy d

-- Join to accounts
JOIN dbo.accounts a ON d.account_id = a.account_id

-- Join aggregated payments
LEFT JOIN (
  SELECT
    account_id,
    MAX(payment_date) AS last_payment_date,
    SUM(CAST(amount AS DECIMAL(12,2))) AS total_payments,
    AVG(CAST(amount AS DECIMAL(12,2))) AS avg_payment
  FROM dbo.payments
  GROUP BY account_id
) p ON d.account_id = p.account_id

-- Join latest outreach
LEFT JOIN (
  SELECT
    account_id,
    contact_date,
    channel,
    outcome,
    contact_id,
    ROW_NUMBER() OVER (PARTITION BY account_id ORDER BY contact_date DESC) AS rn
  FROM dbo.outreach
) o ON d.account_id = o.account_id AND o.rn = 1

-- Join PTP follow-up
LEFT JOIN dbo.followup f ON o.contact_id = f.contact_id;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:08:18.542
